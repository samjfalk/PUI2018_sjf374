# %%
# the bus name,
# the number of vehicles
# their current position

# %%
#testing
import sys
import json
try:
    import urllib2 as urllib
except ImportError:
    import urllib.request as urllib

key = 
bus = 'M15-SBS'

bus = bus.upper()

full_url = \
'http://bustime.mta.info/api/siri/vehicle-monitoring.json?key=%s&VehicleMonitoringDetailLevel=calls&LineRef=%s'\
% (key, bus)

#seen in class notes
response = urllib.urlopen(full_url)
data = response.read().decode("utf-8")
parsedjson = json.loads(data, parse_constant= True)

# %%
parsedjson.keys()
# Out:
# dict_keys(['Siri'])

# %%
busactivity = parsedjson['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity']

print ('Bus Line : ' + bus)

print ('Number of Active Buses : ' + str(len(busactivity)))

i = 0
for x in busactivity:
    print ('Bus %s is at latitude %s and longitude %s' % (i, str(x['MonitoredVehicleJourney']['VehicleLocation']['Latitude']), str(x['MonitoredVehicleJourney']['VehicleLocation']['Longitude'])))
    i+=1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-69-96c59e116b28> in <module>()
# ----> 1 busactivity = parsedjson['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity']
#       2
#       3 print ('Bus Line : ' + bus)
#       4
#       5 print ('Number of Active Buses : ' + str(len(busactivity)))
#
# KeyError: 'VehicleActivity'

# %%
for x in busactivity:
    print (x['MonitoredVehicleJourney']['VehicleLocation']['Latitude'])
    print (x['MonitoredVehicleJourney']['VehicleLocation']['Longitude'])
    print (x['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][0]['StopPointName'])
    print (x['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][0]['Extensions']['Distances']['PresentableDistance'])
# Out:
# 40.757127
# -73.966886
# 2 AV/E 54 ST
# at stop
# 40.747643
# -73.973804
# 2 AV/E 39 ST
# at stop
# 40.725369
# -73.990016
# 2 AV/E 3 ST
# at stop
# 40.701584
# -74.012038
# SOUTH ST/WHITEHALL ST
# at stop
# 40.76746
# -73.959334
# 2 AV/E 70 ST
# at stop
# 40.706216
# -74.005896
# WATER ST/MAIDEN LA
# approaching
# 40.701676
# -74.011606
# SOUTH ST/WHITEHALL ST
# approaching
# 40.789146
# -73.943508
# 2 AV/E 103 ST
# approaching
# 40.711927
# -73.998137
# MADISON ST/CATHERINE ST
# approaching
# 40.788236
# -73.944176
# 2 AV/E 101 ST
# approaching
# 40.737427
# -73.978146
# 1 AV/E 25 ST
# approaching
# 40.712956
# -73.992354
# PIKE ST/DIVISION ST
# approaching
# 40.795092
# -73.93607
# 1 AV/E 116 ST
# < 1 stop away
# 40.757502
# -73.963496
# 1 AV/E 57 ST
# < 1 stop away

# %%
busactivity
# Out:
# [{'MonitoredVehicleJourney': {'LineRef': 'MTA NYCT_B48',
#    'DirectionRef': '1',
#    'FramedVehicleJourneyRef': {'DataFrameRef': '2018-09-26',
#     'DatedVehicleJourneyRef': 'MTA NYCT_GA_D8-Weekday-SDon-125000_B48_513'},
#    'JourneyPatternRef': 'MTA_B480071',
#    'PublishedLineName': 'B48',
#    'OperatorRef': 'MTA NYCT',
#    'OriginRef': 'MTA_306480',
#    'DestinationRef': 'MTA_801030',
#    'DestinationName': 'LEFFERTS GARDENS PROSPECT PK STA',
#    'SituationRef': [],
#    'Monitored': True,
#    'VehicleLocation': {'Longitude': -73.953686, 'Latitude': 40.700326},
#    'Bearing': 212.87898,
#    'ProgressRate': 'normalProgress',
#    'BlockRef': 'MTA NYCT_GA_D8-Weekday-SDon_E_GA_65100_B48-513',
#    'VehicleRef': 'MTA NYCT_7233',
#    'MonitoredCall': {'ExpectedArrivalTime': '2018-09-26T21:11:53.584-04:00',
#     'ExpectedDepartureTime': '2018-09-26T21:11:53.584-04:00',
#     'Extensions': {'Distances': {'PresentableDistance': 'at stop',
#       'DistanceFromCall': 6.01,
#       'StopsFromCall': 0,
#       'CallDistanceAlongRoute': 4501.88}},
#     'StopPointRef': 'MTA_303864',
#     'VisitNumber': 1,
#     'StopPointName': 'LORIMER ST/LEE AV'},
#    'OnwardCalls': {'OnwardCall': [{'ExpectedArrivalTime': '2018-09-26T21:11:52.584-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': 'at stop',
#         'DistanceFromCall': 6.01,
#         'StopsFromCall': 0,
#         'CallDistanceAlongRoute': 4501.88}},
#       'StopPointRef': 'MTA_303864',
#       'StopPointName': 'LORIMER ST/LEE AV'},
#      {'ExpectedArrivalTime': '2018-09-26T21:13:09.020-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '1 stop away',
#         'DistanceFromCall': 303.4,
#         'StopsFromCall': 1,
#         'CallDistanceAlongRoute': 4799.26}},
#       'StopPointRef': 'MTA_303865',
#       'StopPointName': 'WALLABOUT ST/BEDFORD AV'},
#      {'ExpectedArrivalTime': '2018-09-26T21:13:54.072-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '2 stops away',
#         'DistanceFromCall': 462.68,
#         'StopsFromCall': 2,
#         'CallDistanceAlongRoute': 4958.54}},
#       'StopPointRef': 'MTA_303866',
#       'StopPointName': 'WALLABOUT ST/WYTHE AV'},
#      {'ExpectedArrivalTime': '2018-09-26T21:15:23.034-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '3 stops away',
#         'DistanceFromCall': 592.59,
#         'StopsFromCall': 3,
#         'CallDistanceAlongRoute': 5088.46}},
#       'StopPointRef': 'MTA_307169',
#       'StopPointName': 'FRANKLIN AV/FLUSHING AV'},
#      {'ExpectedArrivalTime': '2018-09-26T21:16:22.284-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '0.5 miles away',
#         'DistanceFromCall': 828.06,
#         'StopsFromCall': 4,
#         'CallDistanceAlongRoute': 5323.93}},
#       'StopPointRef': 'MTA_303868',
#       'StopPointName': 'FRANKLIN AV/PARK AV'},
#      {'ExpectedArrivalTime': '2018-09-26T21:17:40.607-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '0.7 miles away',
#         'DistanceFromCall': 1077.96,
#         'StopsFromCall': 5,
#         'CallDistanceAlongRoute': 5573.83}},
#       'StopPointRef': 'MTA_303869',
#       'StopPointName': 'FRANKLIN AV/MYRTLE AV'},
#      {'ExpectedArrivalTime': '2018-09-26T21:18:39.442-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '0.8 miles away',
#         'DistanceFromCall': 1253.33,
#         'StopsFromCall': 6,
#         'CallDistanceAlongRoute': 5749.2}},
#       'StopPointRef': 'MTA_303870',
#       'StopPointName': 'FRANKLIN AV/WILLOUGHBY AV'},
#      {'ExpectedArrivalTime': '2018-09-26T21:19:30.899-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '0.9 miles away',
#         'DistanceFromCall': 1492.1,
#         'StopsFromCall': 7,
#         'CallDistanceAlongRoute': 5987.96}},
#       'StopPointRef': 'MTA_303871',
#       'StopPointName': 'FRANKLIN AV/DE KALB AV'},
#      {'ExpectedArrivalTime': '2018-09-26T21:20:14.499-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '1.0 miles away',
#         'DistanceFromCall': 1611.4,
#         'StopsFromCall': 8,
#         'CallDistanceAlongRoute': 6107.27}},
#       'StopPointRef': 'MTA_303872',
#       'StopPointName': 'FRANKLIN AV/LAFAYETTE AV'},
#      {'ExpectedArrivalTime': '2018-09-26T21:21:15.899-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '1.1 miles away',
#         'DistanceFromCall': 1825.74,
#         'StopsFromCall': 9,
#         'CallDistanceAlongRoute': 6321.61}},
#       'StopPointRef': 'MTA_307553',
#       'StopPointName': 'FRANKLIN AV/GREENE AV'},
#      {'ExpectedArrivalTime': '2018-09-26T21:22:06.565-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '1.3 miles away',
#         'DistanceFromCall': 2022.58,
#         'StopsFromCall': 10,
#         'CallDistanceAlongRoute': 6518.45}},
#       'StopPointRef': 'MTA_303874',
#       'StopPointName': 'FRANKLIN AV/GATES AV'},
#      {'ExpectedArrivalTime': '2018-09-26T21:22:46.805-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '1.4 miles away',
#         'DistanceFromCall': 2236.96,
#         'StopsFromCall': 11,
#         'CallDistanceAlongRoute': 6732.83}},
#       'StopPointRef': 'MTA_303875',
#       'StopPointName': 'FRANKLIN AV/MADISON ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:23:00.898-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '1.4 miles away',
#         'DistanceFromCall': 2325.14,
#         'StopsFromCall': 12,
#         'CallDistanceAlongRoute': 6821.0}},
#       'StopPointRef': 'MTA_303876',
#       'StopPointName': 'FRANKLIN AV/PUTNAM AV'},
#      {'ExpectedArrivalTime': '2018-09-26T21:23:58.763-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '1.6 miles away',
#         'DistanceFromCall': 2590.88,
#         'StopsFromCall': 13,
#         'CallDistanceAlongRoute': 7086.75}},
#       'StopPointRef': 'MTA_308073',
#       'StopPointName': 'FRANKLIN AV/FULTON ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:26:27.800-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '1.9 miles away',
#         'DistanceFromCall': 3008.21,
#         'StopsFromCall': 14,
#         'CallDistanceAlongRoute': 7504.08}},
#       'StopPointRef': 'MTA_303880',
#       'StopPointName': 'FRANKLIN AV/BERGEN ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:27:58.600-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '2.0 miles away',
#         'DistanceFromCall': 3258.26,
#         'StopsFromCall': 15,
#         'CallDistanceAlongRoute': 7754.12}},
#       'StopPointRef': 'MTA_303881',
#       'StopPointName': 'FRANKLIN AV/PROSPECT PL'},
#      {'ExpectedArrivalTime': '2018-09-26T21:29:05.800-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '2.1 miles away',
#         'DistanceFromCall': 3414.29,
#         'StopsFromCall': 16,
#         'CallDistanceAlongRoute': 7910.15}},
#       'StopPointRef': 'MTA_303882',
#       'StopPointName': 'FRANKLIN AV/STERLING PL'},
#      {'ExpectedArrivalTime': '2018-09-26T21:30:05.000-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '2.2 miles away',
#         'DistanceFromCall': 3564.91,
#         'StopsFromCall': 17,
#         'CallDistanceAlongRoute': 8060.77}},
#       'StopPointRef': 'MTA_303883',
#       'StopPointName': 'FRANKLIN AV/ST JOHNS PL'},
#      {'ExpectedArrivalTime': '2018-09-26T21:31:03.800-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '2.3 miles away',
#         'DistanceFromCall': 3696.98,
#         'StopsFromCall': 18,
#         'CallDistanceAlongRoute': 8192.84}},
#       'StopPointRef': 'MTA_303884',
#       'StopPointName': 'FRANKLIN AV/EASTERN PY'},
#      {'ExpectedArrivalTime': '2018-09-26T21:32:13.521-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '2.4 miles away',
#         'DistanceFromCall': 3865.07,
#         'StopsFromCall': 19,
#         'CallDistanceAlongRoute': 8360.93}},
#       'StopPointRef': 'MTA_303885',
#       'StopPointName': 'FRANKLIN AV/UNION ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:33:07.233-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '2.5 miles away',
#         'DistanceFromCall': 4071.33,
#         'StopsFromCall': 20,
#         'CallDistanceAlongRoute': 8567.2}},
#       'StopPointRef': 'MTA_303886',
#       'StopPointName': 'FRANKLIN AV/CARROLL ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:34:01.564-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '2.7 miles away',
#         'DistanceFromCall': 4273.16,
#         'StopsFromCall': 21,
#         'CallDistanceAlongRoute': 8769.03}},
#       'StopPointRef': 'MTA_303887',
#       'StopPointName': 'FRANKLIN AV/MONTGOMERY ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:35:06.564-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '2.8 miles away',
#         'DistanceFromCall': 4535.6,
#         'StopsFromCall': 22,
#         'CallDistanceAlongRoute': 9031.47}},
#       'StopPointRef': 'MTA_303888',
#       'StopPointName': 'SULLIVAN PL/WASHINGTON AV'},
#      {'ExpectedArrivalTime': '2018-09-26T21:36:12.700-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '2.9 miles away',
#         'DistanceFromCall': 4656.38,
#         'StopsFromCall': 23,
#         'CallDistanceAlongRoute': 9152.25}},
#       'StopPointRef': 'MTA_303791',
#       'StopPointName': 'WASHINGTON AV/EMPIRE BL'},
#      {'ExpectedArrivalTime': '2018-09-26T21:38:25.900-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '3.1 miles away',
#         'DistanceFromCall': 5009.55,
#         'StopsFromCall': 24,
#         'CallDistanceAlongRoute': 9505.41}},
#       'StopPointRef': 'MTA_801030',
#       'StopPointName': 'LINCOLN RD/FLATBUSH AV'}]}},
#   'RecordedAtTime': '2018-09-26T21:11:28.000-04:00'},
#  {'MonitoredVehicleJourney': {'LineRef': 'MTA NYCT_B48',
#    'DirectionRef': '0',
#    'FramedVehicleJourneyRef': {'DataFrameRef': '2018-09-26',
#     'DatedVehicleJourneyRef': 'MTA NYCT_GA_D8-Weekday-SDon-122500_B48_515'},
#    'JourneyPatternRef': 'MTA_B480072',
#    'PublishedLineName': 'B48',
#    'OperatorRef': 'MTA NYCT',
#    'OriginRef': 'MTA_308076',
#    'DestinationRef': 'MTA_801031',
#    'DestinationName': 'GREENPOINT MEEKER AV',
#    'SituationRef': [],
#    'Monitored': True,
#    'VehicleLocation': {'Longitude': -73.951625, 'Latitude': 40.701658},
#    'Bearing': 32.735226,
#    'ProgressRate': 'normalProgress',
#    'BlockRef': 'MTA NYCT_GA_D8-Weekday-SDon_E_GA_68700_B48-515',
#    'VehicleRef': 'MTA NYCT_7244',
#    'MonitoredCall': {'ExpectedArrivalTime': '2018-09-26T21:12:09.396-04:00',
#     'ExpectedDepartureTime': '2018-09-26T21:12:09.396-04:00',
#     'Extensions': {'Distances': {'PresentableDistance': '< 1 stop away',
#       'DistanceFromCall': 217.04,
#       'StopsFromCall': 0,
#       'CallDistanceAlongRoute': 5807.85}},
#     'StopPointRef': 'MTA_303817',
#     'VisitNumber': 1,
#     'StopPointName': 'LORIMER ST/HARRISON AV'},
#    'OnwardCalls': {'OnwardCall': [{'ExpectedArrivalTime': '2018-09-26T21:12:09.396-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '< 1 stop away',
#         'DistanceFromCall': 217.04,
#         'StopsFromCall': 0,
#         'CallDistanceAlongRoute': 5807.85}},
#       'StopPointRef': 'MTA_303817',
#       'StopPointName': 'LORIMER ST/HARRISON AV'},
#      {'ExpectedArrivalTime': '2018-09-26T21:12:52.846-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '1 stop away',
#         'DistanceFromCall': 405.86,
#         'StopsFromCall': 1,
#         'CallDistanceAlongRoute': 5996.68}},
#       'StopPointRef': 'MTA_303818',
#       'StopPointName': 'LORIMER ST/BROADWAY'},
#      {'ExpectedArrivalTime': '2018-09-26T21:14:15.213-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '2 stops away',
#         'DistanceFromCall': 605.57,
#         'StopsFromCall': 2,
#         'CallDistanceAlongRoute': 6196.39}},
#       'StopPointRef': 'MTA_303819',
#       'StopPointName': 'LORIMER ST/BOERUM ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:15:05.236-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '0.5 miles away',
#         'DistanceFromCall': 842.28,
#         'StopsFromCall': 3,
#         'CallDistanceAlongRoute': 6433.1}},
#       'StopPointRef': 'MTA_303820',
#       'StopPointName': 'LORIMER ST/MESEROLE ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:15:44.834-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '0.6 miles away',
#         'DistanceFromCall': 1000.16,
#         'StopsFromCall': 4,
#         'CallDistanceAlongRoute': 6590.98}},
#       'StopPointRef': 'MTA_303821',
#       'StopPointName': 'LORIMER ST/STAGG ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:16:47.834-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '0.8 miles away',
#         'DistanceFromCall': 1224.72,
#         'StopsFromCall': 5,
#         'CallDistanceAlongRoute': 6815.53}},
#       'StopPointRef': 'MTA_303823',
#       'StopPointName': 'LORIMER ST/GRAND ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:17:18.634-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '0.8 miles away',
#         'DistanceFromCall': 1324.42,
#         'StopsFromCall': 6,
#         'CallDistanceAlongRoute': 6915.23}},
#       'StopPointRef': 'MTA_303824',
#       'StopPointName': 'LORIMER ST/POWERS ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:18:01.821-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '0.9 miles away',
#         'DistanceFromCall': 1484.01,
#         'StopsFromCall': 7,
#         'CallDistanceAlongRoute': 7074.82}},
#       'StopPointRef': 'MTA_303825',
#       'StopPointName': 'LORIMER ST/DEVOE ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:19:04.764-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '1.0 miles away',
#         'DistanceFromCall': 1639.21,
#         'StopsFromCall': 8,
#         'CallDistanceAlongRoute': 7230.02}},
#       'StopPointRef': 'MTA_303826',
#       'StopPointName': 'LORIMER ST/CONSELYEA ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:19:37.164-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '1.1 miles away',
#         'DistanceFromCall': 1759.62,
#         'StopsFromCall': 9,
#         'CallDistanceAlongRoute': 7350.43}},
#       'StopPointRef': 'MTA_303827',
#       'StopPointName': 'LORIMER ST/JACKSON ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:20:45.482-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '1.2 miles away',
#         'DistanceFromCall': 1962.18,
#         'StopsFromCall': 10,
#         'CallDistanceAlongRoute': 7553.0}},
#       'StopPointRef': 'MTA_303828',
#       'StopPointName': 'LORIMER ST/FROST ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:21:21.082-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '1.3 miles away',
#         'DistanceFromCall': 2141.11,
#         'StopsFromCall': 11,
#         'CallDistanceAlongRoute': 7731.93}},
#       'StopPointRef': 'MTA_303829',
#       'StopPointName': 'LORIMER ST/BAYARD ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:22:07.453-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '1.5 miles away',
#         'DistanceFromCall': 2381.22,
#         'StopsFromCall': 12,
#         'CallDistanceAlongRoute': 7972.04}},
#       'StopPointRef': 'MTA_303830',
#       'StopPointName': 'LORIMER ST/DRIGGS AV'},
#      {'ExpectedArrivalTime': '2018-09-26T21:23:10.053-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '1.6 miles away',
#         'DistanceFromCall': 2593.26,
#         'StopsFromCall': 13,
#         'CallDistanceAlongRoute': 8184.07}},
#       'StopPointRef': 'MTA_303831',
#       'StopPointName': 'LORIMER ST/NASSAU AV'},
#      {'ExpectedArrivalTime': '2018-09-26T21:24:33.853-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '1.7 miles away',
#         'DistanceFromCall': 2733.8,
#         'StopsFromCall': 14,
#         'CallDistanceAlongRoute': 8324.62}},
#       'StopPointRef': 'MTA_307096',
#       'StopPointName': 'NASSAU AV/MANHATTAN AV'},
#      {'ExpectedArrivalTime': '2018-09-26T21:26:05.273-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '1.8 miles away',
#         'DistanceFromCall': 2899.23,
#         'StopsFromCall': 15,
#         'CallDistanceAlongRoute': 8490.05}},
#       'StopPointRef': 'MTA_303833',
#       'StopPointName': 'NASSAU AV/MC GUINNESS BL'},
#      {'ExpectedArrivalTime': '2018-09-26T21:27:41.244-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '2.0 miles away',
#         'DistanceFromCall': 3147.52,
#         'StopsFromCall': 16,
#         'CallDistanceAlongRoute': 8738.34}},
#       'StopPointRef': 'MTA_303835',
#       'StopPointName': 'NASSAU AV/HUMBOLDT ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:28:49.100-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '2.1 miles away',
#         'DistanceFromCall': 3437.76,
#         'StopsFromCall': 17,
#         'CallDistanceAlongRoute': 9028.58}},
#       'StopPointRef': 'MTA_303837',
#       'StopPointName': 'NASSAU AV/MONITOR ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:29:52.500-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '2.3 miles away',
#         'DistanceFromCall': 3673.5,
#         'StopsFromCall': 18,
#         'CallDistanceAlongRoute': 9264.31}},
#       'StopPointRef': 'MTA_801090',
#       'StopPointName': 'NASSAU AV/MORGAN ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:30:27.808-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '2.4 miles away',
#         'DistanceFromCall': 3856.88,
#         'StopsFromCall': 19,
#         'CallDistanceAlongRoute': 9447.7}},
#       'StopPointRef': 'MTA_308322',
#       'StopPointName': 'NASSAU AV/VAN DAM ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:31:36.960-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '2.6 miles away',
#         'DistanceFromCall': 4173.04,
#         'StopsFromCall': 20,
#         'CallDistanceAlongRoute': 9763.86}},
#       'StopPointRef': 'MTA_801031',
#       'StopPointName': 'MEEKER AV/STEWART AV'}]}},
#   'RecordedAtTime': '2018-09-26T21:11:03.000-04:00'},
#  {'MonitoredVehicleJourney': {'LineRef': 'MTA NYCT_B48',
#    'DirectionRef': '0',
#    'FramedVehicleJourneyRef': {'DataFrameRef': '2018-09-26',
#     'DatedVehicleJourneyRef': 'MTA NYCT_GA_D8-Weekday-SDon-125000_B47_420'},
#    'JourneyPatternRef': 'MTA_B480072',
#    'PublishedLineName': 'B48',
#    'OperatorRef': 'MTA NYCT',
#    'OriginRef': 'MTA_308076',
#    'DestinationRef': 'MTA_801031',
#    'DestinationName': 'GREENPOINT MEEKER AV',
#    'SituationRef': [],
#    'Monitored': True,
#    'VehicleLocation': {'Longitude': -73.952153, 'Latitude': 40.701317},
#    'Bearing': 32.879692,
#    'ProgressRate': 'normalProgress',
#    'BlockRef': 'MTA NYCT_GA_D8-Weekday-SDon_E_GA_70500_B47-420',
#    'VehicleRef': 'MTA NYCT_4113',
#    'MonitoredCall': {'ExpectedArrivalTime': '2018-09-26T21:13:01.272-04:00',
#     'ExpectedDepartureTime': '2018-09-26T21:13:01.272-04:00',
#     'Extensions': {'Distances': {'PresentableDistance': '< 1 stop away',
#       'DistanceFromCall': 275.47,
#       'StopsFromCall': 0,
#       'CallDistanceAlongRoute': 5807.85}},
#     'StopPointRef': 'MTA_303817',
#     'VisitNumber': 1,
#     'StopPointName': 'LORIMER ST/HARRISON AV'},
#    'OnwardCalls': {'OnwardCall': [{'ExpectedArrivalTime': '2018-09-26T21:13:01.272-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '< 1 stop away',
#         'DistanceFromCall': 275.47,
#         'StopsFromCall': 0,
#         'CallDistanceAlongRoute': 5807.85}},
#       'StopPointRef': 'MTA_303817',
#       'StopPointName': 'LORIMER ST/HARRISON AV'},
#      {'ExpectedArrivalTime': '2018-09-26T21:13:44.722-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '1 stop away',
#         'DistanceFromCall': 464.3,
#         'StopsFromCall': 1,
#         'CallDistanceAlongRoute': 5996.68}},
#       'StopPointRef': 'MTA_303818',
#       'StopPointName': 'LORIMER ST/BROADWAY'},
#      {'ExpectedArrivalTime': '2018-09-26T21:15:07.089-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '2 stops away',
#         'DistanceFromCall': 664.01,
#         'StopsFromCall': 2,
#         'CallDistanceAlongRoute': 6196.39}},
#       'StopPointRef': 'MTA_303819',
#       'StopPointName': 'LORIMER ST/BOERUM ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:15:57.112-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '0.6 miles away',
#         'DistanceFromCall': 900.72,
#         'StopsFromCall': 3,
#         'CallDistanceAlongRoute': 6433.1}},
#       'StopPointRef': 'MTA_303820',
#       'StopPointName': 'LORIMER ST/MESEROLE ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:16:36.710-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '0.7 miles away',
#         'DistanceFromCall': 1058.6,
#         'StopsFromCall': 4,
#         'CallDistanceAlongRoute': 6590.98}},
#       'StopPointRef': 'MTA_303821',
#       'StopPointName': 'LORIMER ST/STAGG ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:17:39.710-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '0.8 miles away',
#         'DistanceFromCall': 1283.15,
#         'StopsFromCall': 5,
#         'CallDistanceAlongRoute': 6815.53}},
#       'StopPointRef': 'MTA_303823',
#       'StopPointName': 'LORIMER ST/GRAND ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:18:10.510-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '0.9 miles away',
#         'DistanceFromCall': 1382.85,
#         'StopsFromCall': 6,
#         'CallDistanceAlongRoute': 6915.23}},
#       'StopPointRef': 'MTA_303824',
#       'StopPointName': 'LORIMER ST/POWERS ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:18:53.697-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '1.0 miles away',
#         'DistanceFromCall': 1542.44,
#         'StopsFromCall': 7,
#         'CallDistanceAlongRoute': 7074.82}},
#       'StopPointRef': 'MTA_303825',
#       'StopPointName': 'LORIMER ST/DEVOE ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:19:56.640-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '1.1 miles away',
#         'DistanceFromCall': 1697.64,
#         'StopsFromCall': 8,
#         'CallDistanceAlongRoute': 7230.02}},
#       'StopPointRef': 'MTA_303826',
#       'StopPointName': 'LORIMER ST/CONSELYEA ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:20:29.040-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '1.1 miles away',
#         'DistanceFromCall': 1818.05,
#         'StopsFromCall': 9,
#         'CallDistanceAlongRoute': 7350.43}},
#       'StopPointRef': 'MTA_303827',
#       'StopPointName': 'LORIMER ST/JACKSON ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:21:37.358-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '1.3 miles away',
#         'DistanceFromCall': 2020.62,
#         'StopsFromCall': 10,
#         'CallDistanceAlongRoute': 7553.0}},
#       'StopPointRef': 'MTA_303828',
#       'StopPointName': 'LORIMER ST/FROST ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:22:12.958-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '1.4 miles away',
#         'DistanceFromCall': 2199.55,
#         'StopsFromCall': 11,
#         'CallDistanceAlongRoute': 7731.93}},
#       'StopPointRef': 'MTA_303829',
#       'StopPointName': 'LORIMER ST/BAYARD ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:22:59.329-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '1.5 miles away',
#         'DistanceFromCall': 2439.65,
#         'StopsFromCall': 12,
#         'CallDistanceAlongRoute': 7972.04}},
#       'StopPointRef': 'MTA_303830',
#       'StopPointName': 'LORIMER ST/DRIGGS AV'},
#      {'ExpectedArrivalTime': '2018-09-26T21:24:01.929-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '1.6 miles away',
#         'DistanceFromCall': 2651.69,
#         'StopsFromCall': 13,
#         'CallDistanceAlongRoute': 8184.07}},
#       'StopPointRef': 'MTA_303831',
#       'StopPointName': 'LORIMER ST/NASSAU AV'},
#      {'ExpectedArrivalTime': '2018-09-26T21:25:25.729-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '1.7 miles away',
#         'DistanceFromCall': 2792.24,
#         'StopsFromCall': 14,
#         'CallDistanceAlongRoute': 8324.62}},
#       'StopPointRef': 'MTA_307096',
#       'StopPointName': 'NASSAU AV/MANHATTAN AV'},
#      {'ExpectedArrivalTime': '2018-09-26T21:26:57.149-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '1.8 miles away',
#         'DistanceFromCall': 2957.67,
#         'StopsFromCall': 15,
#         'CallDistanceAlongRoute': 8490.05}},
#       'StopPointRef': 'MTA_303833',
#       'StopPointName': 'NASSAU AV/MC GUINNESS BL'},
#      {'ExpectedArrivalTime': '2018-09-26T21:28:33.120-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '2.0 miles away',
#         'DistanceFromCall': 3205.95,
#         'StopsFromCall': 16,
#         'CallDistanceAlongRoute': 8738.34}},
#       'StopPointRef': 'MTA_303835',
#       'StopPointName': 'NASSAU AV/HUMBOLDT ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:29:40.976-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '2.2 miles away',
#         'DistanceFromCall': 3496.2,
#         'StopsFromCall': 17,
#         'CallDistanceAlongRoute': 9028.58}},
#       'StopPointRef': 'MTA_303837',
#       'StopPointName': 'NASSAU AV/MONITOR ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:30:44.376-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '2.3 miles away',
#         'DistanceFromCall': 3731.93,
#         'StopsFromCall': 18,
#         'CallDistanceAlongRoute': 9264.31}},
#       'StopPointRef': 'MTA_801090',
#       'StopPointName': 'NASSAU AV/MORGAN ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:31:19.684-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '2.4 miles away',
#         'DistanceFromCall': 3915.32,
#         'StopsFromCall': 19,
#         'CallDistanceAlongRoute': 9447.7}},
#       'StopPointRef': 'MTA_308322',
#       'StopPointName': 'NASSAU AV/VAN DAM ST'},
#      {'ExpectedArrivalTime': '2018-09-26T21:32:28.836-04:00',
#       'Extensions': {'Distances': {'PresentableDistance': '2.6 miles away',
#         'DistanceFromCall': 4231.48,
#         'StopsFromCall': 20,
#         'CallDistanceAlongRoute': 9763.86}},
#       'StopPointRef': 'MTA_801031',
#       'StopPointName': 'MEEKER AV/STEWART AV'}]}},
#   'RecordedAtTime': '2018-09-26T21:11:37.000-04:00'}]

# %%
def bus_location(key, bus, file):
	#in case it is input as lower case-- mta does not recognize it
	bus = bus.upper()
	#input variables into the URL
	full_url = \
	'http://bustime.mta.info/api/siri/vehicle-monitoring.json?key=%s&VehicleMonitoringDetailLevel=calls&LineRef=%s'\
	% (key, bus)

	#seen in class notes
	response = urllib.urlopen(full_url)
	data = response.read().decode("utf-8")
	parsedjson = json.loads(data, parse_constant= True)

	#filter down dictionaries to dictionary with vehicle activity
	busactivity = parsedjson['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity']

	print ('Bus Line : ' + bus)

	#find how many buses
	print ('Number of Active Buses : ' + str(len(busactivity)))

	#open file to write
	fout = open(file, "w")

	#create headers
	fout.write("Latitude,Longitude,Stop Name,Stop Status\n")

	#show each bus and their corresponding location
	for x in busactivity:
		lat = x['MonitoredVehicleJourney']['VehicleLocation']['Latitude']
		Long = x['MonitoredVehicleJourney']['VehicleLocation']['Longitude']	try:
    		stopname =  x['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][0]['StopPointName']
		except:
			stopname= 'N/A'
		try:
			status =  x['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][0]['Extensions']['Distances']['PresentableDistance']
		except:
			status = 'N/A'

		fout.write(Lat+','+Long+','+stopname+','+status+'\n')
# Out:
#   File "<ipython-input-46-7efa960f42a8>", line 30
#     try:
#         ^
# TabError: inconsistent use of tabs and spaces in indentation

# %%
bus_location(key, bus, file)
